# %% [markdown]
# # Task 3 - (Level - Intermediate)
# **Prediction using Decision Tree Algorithm**
#
# For the given ‘Iris’ dataset, create the Decision Tree classifier and visualize it graphically.
#
# In this task, we have to make a classifier such that if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# Prepared By: Uday Juneja

# %% [markdown]
# **Importing the libraries**

# %%
import sklearn.datasets as datasets
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the Dataset**

# %%
t3=pd.read_csv(r"D:\Notes\Sparks\Iris.csv")

# %% [markdown]
# **Describing the Data**

# %%
t3.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
t3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# **Visualization of the data**

# %%
print(t3["Species"].value_counts()) 
sns.countplot(x="Species", data=t3)
plt.show()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
sns.swarmplot(x="Species", y="SepalLengthCm", data=t3)
plt.show()

# %%
sns.swarmplot(x="Species", y="SepalWidthCm", data=t3)
plt.show()

# %%
sns.swarmplot(x="Species", y="PetalLengthCm", data=t3)
plt.show()

# %%
sns.swarmplot(x="Species", y="PetalWidthCm", data=t3)
plt.show()

# %% [markdown]
# **Preparing Training and Testing Data**

# %%
from sklearn.model_selection import train_test_split
X= t3.iloc [:,1:-1]
Y= t3.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %% [markdown]
# **Building the classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
lm= DecisionTreeClassifier(random_state=0)
lm.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# **Checking accuracy of Data**

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
Y_train_pred=lm.predict(X_train)
Y_test_pred=lm.predict(X_test)
print("Train accuracy score:",accuracy_score(Y_train,Y_train_pred))
print("Test accuracy score:",accuracy_score(Y_test,Y_test_pred))
# Out:
# Train accuracy score: 1.0
# Test accuracy score: 0.9777777777777777

# %% [markdown]
# **Visualization of the Desicion Tree**

# %%
from sklearn.tree import plot_tree
plt.figure (figsize=(15,15))
plot_tree(lm,filled= True)
print()
